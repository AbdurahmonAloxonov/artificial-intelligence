# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdurahmonAloxonov/artificial-intelligence/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Ma'lumotni yuklash
data = pd.read_csv('/content/athlete_training.csv')
X = data['Training Hours per Week'].values.reshape(-1, 1)
y = data['Running Time (minutes)'].values

# %%
# Polynomial xususiyatlar (daraja = 2)
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)

# %%
# Modelni o‘qitish
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Bashorat
y_pred = model.predict(X_poly)

# %%
# Baholash
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
# Grafik uchun tartib
sort_idx = X.flatten().argsort()
X_sorted = X[sort_idx].reshape(-1, 1)
X_poly_sorted = poly_features.transform(X_sorted)
y_curve = model.predict(X_poly_sorted)

# %%
# Chizish
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X_sorted, y_curve, color='red', label='Polynomial regression (degree=2)')
plt.title('Training Hours vs Running Time')
plt.xlabel('Training Hours per Week')
plt.ylabel('Running Time (minutes for 5 km)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Natijalar
print("Polynomial regression results:")
print(f"MSE: {mse:.2f}")
print(f"R²: {r2:.4f}")
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Polynomial regression results:
# MSE: 0.16
# R²: 0.9910
# Coefficients: [ 0.         -3.18204545  0.1625    ]
# Intercept: 33.51500000000001

# %%
# Bashorat funksiyasi
def predict_running_time(hours):
    hours_array = np.array([hours]).reshape(-1, 1)
    hours_poly = poly_features.transform(hours_array)
    predicted_time = model.predict(hours_poly)
    return predicted_time[0]

# %%
# Namuna bashoratlar
print("\nSample predictions:")
test_hours = [1, 3, 5, 7, 10]
for h in test_hours:
    result = predict_running_time(h)
    print(f"If an athlete trains {h} hours/week, predicted running time: {result:.2f} minutes")
# Out:
# Sample predictions:
# If an athlete trains 1 hours/week, predicted running time: 30.50 minutes
# If an athlete trains 3 hours/week, predicted running time: 25.43 minutes
# If an athlete trains 5 hours/week, predicted running time: 21.67 minutes
# If an athlete trains 7 hours/week, predicted running time: 19.20 minutes
# If an athlete trains 10 hours/week, predicted running time: 17.94 minutes
